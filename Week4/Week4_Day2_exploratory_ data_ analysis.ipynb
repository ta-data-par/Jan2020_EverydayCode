# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Multiple-line-plots" data-toc-modified-id="Multiple-line-plots-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Multiple line plots</a></span></li></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/shivalika/Downloads/winequality-white.csv',sep=';')

# %% [markdown]
# Original data is separated by delimiter “ ; “ in given data set.

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# To take a closer look at the data took help of “ .head()”function of pandas library which returns first five observations of the data set.Similarly “.tail()” returns last five observations of the data set.

# %%
df.shape
# Out:
# (4898, 12)

# %% [markdown]
# Dataset comprises of 4898 observations and 12 characteristics.
# Out of which one is dependent variable and rest 11 are independent variables — physico-chemical characteristics.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# Data has only float and integer values.
# No variable column has null/missing values.

# %% [markdown]
# The describe() function in pandas is very handy in getting various summary statistics.This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# Here as you can notice mean value is more than median value of each column which is represented by 50%(50th percentile) in index column.
#
# There is notably a large difference between 75th %tile and max values of predictors “residual sugar”,”free sulfur dioxide”,”total sulfur dioxide”.
#
# Thus observations 1 and 2 suggests that there are extreme values-Outliers in our data set.

# %% [markdown]
# Target variable/Dependent variable is discrete and categorical in nature.
#
# “quality” score scale ranges from 1 to 10;where 1 being poor and 10 being the best.
#
# 1,2 & 10 Quality ratings are not given by any observation. Only scores obtained are between 3 to 9.

# %%
df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# This tells us vote count of each quality score in descending order.
# “quality” has most values concentrated in the categories 5, 6 and 7.
# Only a few observations made for the categories 3 & 9.

# %%
import seaborn as sns
sns.set()

# %%
df_heatmap=df.corr()

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corr_heatmap=sns.heatmap(df_heatmap)

# %%
plt.figure(figsize=(15,15))
corr_heatmap=sns.heatmap(df_heatmap,annot=True)
plt.show()

# %% [markdown]
# Dark shades represents positive correlation while lighter shades represents negative correlation.

# %%
plt.figure(figsize=(15,15))
df.boxplot()
plt.show()

# %%
df.boxplot(column='total sulfur dioxide')

# %%
df.boxplot(column='alcohol')

# %%
sns.violinplot('alcohol',data=df)

# %%
data = pd.read_csv('/home/shivalika/Downloads/vehicles/vehicles/vehicles.csv')

# %%
data
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
data.boxplot(column='Combined MPG')

# %%
data['Fuel Type'].value_counts()
# Out:
# Regular                        23587
# Premium                         9921
# Gasoline or E85                 1195
# Diesel                           911
# Premium or E85                   121
# Midgrade                          74
# CNG                               60
# Gasoline or natural gas           20
# Premium and Electricity           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %%
ax=sns.boxplot(x='Fuel Type',y='Combined MPG',data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
sns.violinplot('Highway MPG',data=data)

# %%
sns.catplot(x='Highway MPG',y='Drivetrain',data=data,hue='Fuel Type')

# %%
sns.catplot(x='Highway MPG',y='Drivetrain',data=data,hue='Fuel Type',col='Cylinders')

# %%
df[:200].nunique()
# Out:
# fixed acidity            32
# volatile acidity         46
# citric acid              46
# residual sugar           92
# chlorides                51
# free sulfur dioxide      67
# total sulfur dioxide    114
# density                  71
# pH                       53
# sulphates                43
# alcohol                  39
# quality                   5
# dtype: int64

# %%
sns.catplot(x='Highway MPG',y='Drivetrain',data=data[:200],col='Fuel Type',hue='Make')

# %%
sns.catplot(y='Highway MPG',x='Drivetrain',data=data[:200],col='Fuel Type',kind='boxen')

# %%
data['CO2 Emission Grams/Mile'].hist()

# %%
data['CO2 Emission Grams/Mile'].hist(bins=50)

# %%
sns.distplot(data['CO2 Emission Grams/Mile'])

# %%
sns.distplot(data['CO2 Emission Grams/Mile'],bins=20)

# %%
data.Drivetrain.value_counts().plot.bar()

# %%
ax=sns.barplot(x='index',y='Drivetrain',data=data.Drivetrain.value_counts().reset_index())
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show()

# %%
data.Drivetrain.value_counts()
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %% [markdown]
# ### Multiple line plots

# %%
data.sort_values(by=["CO2 Emission Grams/Mile", "City MPG", "Highway MPG"], inplace=True)

# %%
data.plot(x="CO2 Emission Grams/Mile", y=["City MPG", "Highway MPG"])

# %%
df_mean = data[["Highway MPG", "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")

# %%
df_mean.plot.bar()

# %%
sns.pairplot(data)

# %%
sns.jointplot('City MPG','Fuel Barrels/Year',data)

# %%
sns.jointplot('City MPG','Fuel Barrels/Year',data,kind='reg')

# %%
sns.jointplot('City MPG','Fuel Barrels/Year',data,kind='hex')
